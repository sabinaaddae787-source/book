# %% [markdown]
# <a href="https://colab.research.google.com/github/sabinaaddae787-source/book/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
DataFrane with column t.t ∈[5,5] with intervals of 0.2:-5,4.8,...,0,...,4.8,5
# Out:
#   File "/tmp/ipython-input-80542131.py", line 1
#     DataFrane with column t.t ∈[5,5] with intervals of 0.2:-5,4.8,...,0,...,4.8,5
#                               ^
# SyntaxError: invalid character '∈' (U+2208)

# %%
my_list=list(range
